# %%
import json

# %%
data_file = open('train-v2.0.json').read()
intents = json.loads(data_file)

# %%
intents=intents["intents"][0:753]

# %%
for i in range(0,len(intents)):
    intents[i]['tag'] = "Beyonc\u00e9 {}".format(i)

# %%
data1={}
data1.update({"intents":intents})

# %%
data1
# Out:
# {'intents': [{'tag': 'Beyoncé 0',
#    'ques': ['When did Beyonce start becoming popular?'],
#    'ans': ['in the late 1990s']},
#   {'tag': 'Beyoncé 1',
#    'ques': ['What areas did Beyonce compete in when she was growing up?'],
#    'ans': ['singing and dancing']},
#   {'tag': 'Beyoncé 2',
#    'ques': ["When did Beyonce leave Destiny's Child and become a solo singer?"],
#    'ans': ['2003']},
#   {'tag': 'Beyoncé 3',
#    'ques': ['In what city and state did Beyonce  grow up? '],
#    'ans': ['Houston, Texas']},
#   {'tag': 'Beyoncé 4',
#    'ques': ['In which decade did Beyonce become famous?'],
#    'ans': ['late 1990s']},
#   {'tag': 'Beyoncé 5',
#    'ques': ['In what R&B group was she the lead singer?'],
#    'ans': ["Destiny's Child"]},
#   {'tag': 'Beyoncé 6',
#    'ques': ['What album made her a worldwide known artist?'],
#    'ans': ['Dangerously in Love']},
#   {'tag': 'Beyoncé 7',
#    'ques': ["Who managed the Destiny's Child group?"],
# ...

# %%
with open("beyonce.json","w") as json_file:
    json.dump(data1,json_file,indent=4,separators=(',' , ': '))
